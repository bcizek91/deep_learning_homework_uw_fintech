# %% [markdown]
# # LSTM Stock Predictor Using Fear and Greed Index
#
# In this notebook, you will build and train a custom LSTM RNN that uses a 10 day window of Bitcoin fear and greed index values to predict the 11th day closing price.
#
# You will need to:
#
# 1. Prepare the data for training and testing
# 2. Build and train a custom LSTM RNN
# 3. Evaluate the performance of the model

# %% [markdown]
# ## Data Preparation
#
# In this section, you will need to prepare the training and testing data for the model. The model will use a rolling 10 day window to predict the 11th day closing price.
#
# You will need to:
# 1. Use the `window_data` function to generate the X and y values for the model.
# 2. Split the data into 70% training and 30% testing
# 3. Apply the MinMaxScaler to the X and y values
# 4. Reshape the X_train and X_test data for the model. Note: The required input format for the LSTM is:
#
# ```python
# reshape((X_train.shape[0], X_train.shape[1], 1))
# ```

# %%
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path

# %%
# Set the random seed for reproducibility
# Note: This is for the homework solution, but it is good practice to comment this out and run multiple experiments to evaluate your model
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)

# %%
# Load the fear and greed sentiment data for Bitcoin
df = pd.read_csv('btc_sentiment.csv', index_col="date", infer_datetime_format=True, parse_dates=True)
df = df.drop(columns="fng_classification")
df.head()
# Out:
#              fng_value
# date
# 2019-07-29          19
# 2019-07-28          16
# 2019-07-27          47
# 2019-07-26          24
# 2019-07-25          42

# %%
# Load the historical closing prices for Bitcoin
df2 = pd.read_csv('btc_historic.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)['Close']
df2 = df2.sort_index()
df2.tail()
# Out:
# Date
# 2019-07-25    9882.429688
# 2019-07-26    9847.450195
# 2019-07-27    9478.320313
# 2019-07-28    9531.769531
# 2019-07-29    9529.889648
# Name: Close, dtype: float64

# %%
# Join the data into a single DataFrame
df = df.join(df2, how="inner")
df.tail()
# Out:
#              fng_value        Close
# 2019-07-25          42  9882.429688
# 2019-07-26          24  9847.450195
# 2019-07-27          47  9478.320313
# 2019-07-28          16  9531.769531
# 2019-07-29          19  9529.889648

# %%
df.head()
# Out:
#              fng_value        Close
# 2018-02-01          30  9114.719727
# 2018-02-02          15  8870.820313
# 2018-02-03          40  9251.269531
# 2018-02-04          24  8218.049805
# 2018-02-05          11  6937.080078

# %%
# This function accepts the column number for the features (X) and the target (y)
# It chunks the data up with a rolling window of Xt-n to predict Xt
# It returns a numpy array of X any y
def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of previous fng values
# Then, experiment with window sizes anywhere from 1 to 10 and see how the model performance changes
window_size = 10

# Column index 0 is the 'fng_value' column
# Column index 1 is the `Close` column
feature_column = 0
target_column = 1
X, y = window_data(df, window_size, feature_column, target_column)

# %%
# Use 70% of the data for training and the remaineder for testing
# YOUR CODE HERE!
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# %%
from sklearn.preprocessing import MinMaxScaler
# Use the MinMaxScaler to scale data between 0 and 1.
# YOUR CODE HERE!

#Create MinMaxScaler Instance
scaler = MinMaxScaler()

#Fit MinMaxScaler object along features data
scaler.fit(X)

#Scale features training & test sets
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

#Fit MinMaxScaler object with target data
scaler.fit(y)

#Scale target training & test sets
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
# YOUR CODE HERE!
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

#Print sample reshaped data
print(f"X_train reshaped values:\n{X_train[:2]} \n")
print(f"X_test reshaped values:\n{X_test[:2]} \n")
# Out:
# X_train reshaped values:
# [[[0.25287356]
#   [0.08045977]
#   [0.36781609]
#   [0.18390805]
#   [0.03448276]
#   [0.        ]
#   [0.31395349]
#   [0.24418605]
#   [0.40697674]
#   [0.52325581]]
#
#  [[0.08045977]
#   [0.36781609]
#   [0.18390805]
#   [0.03448276]
#   [0.        ]
#   [0.32183908]
#   [0.24418605]
#   [0.40697674]
#   [0.52325581]
#   [0.25581395]]]
#
# X_test reshaped values:
# [[[0.36781609]
#   [0.43678161]
#   [0.34482759]
#   [0.45977011]
#   [0.45977011]
#   [0.40229885]
#   [0.39534884]
#   [0.37209302]
#   [0.3372093 ]
#   [0.62790698]]
#
#  [[0.43678161]
#   [0.34482759]
#   [0.45977011]
#   [0.45977011]
#   [0.40229885]
#   [0.40229885]
#   [0.37209302]
#   [0.3372093 ]
#   [0.62790698]
#   [0.65116279]]]

# %% [markdown]
# ---

# %% [markdown]
# ## Build and Train the LSTM RNN
#
# In this section, you will design a custom LSTM RNN and fit (train) it using the training data.
#
# You will need to:
# 1. Define the model architecture
# 2. Compile the model
# 3. Fit the model to the training data
#
# ### Hints:
# You will want to use the same model architecture and random seed for both notebooks. This is necessary to accurately compare the performance of the FNG model vs the closing price model.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Build the LSTM model. 
# The return sequences need to be set to True if you are adding additional LSTM layers, but 
# You don't have to do this for the final layer. 
# Note: The dropouts help prevent overfitting
# Note: The input shape is the number of time steps and the number of indicators
# Note: Batching inputs has a different input shape of Samples/TimeSteps/Features

# YOUR CODE HERE!

#Define LTSM RNN Model
model = Sequential()

#Initialize LTSM model setup
number_units = window_size
dropout_fraction = 0.2

#Layer 1
model.add(LSTM(
    units = number_units,
    return_sequences = True,
    input_shape = (X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))

#Layer 2
model.add(LSTM(
    units = number_units,
    return_sequences = True))
model.add(Dropout(dropout_fraction))

#Layer 3
model.add(LSTM(
    units = number_units,
    return_sequences = True))
model.add(Dropout(dropout_fraction))

#Layer 4
model.add(LSTM(
    units = number_units,
    return_sequences = True))
model.add(Dropout(dropout_fraction))

#Layer 5
model.add(LSTM(
    units = number_units))
model.add(Dropout(dropout_fraction))

#Output Layer
model.add(Dense(1))

# %%
# Compile the model
# YOUR CODE HERE!
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Summarize the model
# YOUR CODE HERE!
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 10)            480
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 10)            840
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 10)            840
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 10)            840
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 10)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10)                840
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 3,851
# Trainable params: 3,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
# Use at least 10 epochs
# Do not shuffle the data
# Experiement with the batch size, but a smaller batch size is recommended
# YOUR CODE HERE!
epochs = 500
batch_size = 30

training_history = model.fit(X_train, y_train, epochs = epochs, shuffle = False, batch_size = batch_size, verbose = 1)
training_history
# Out:
# Epoch 1/500
# 13/13 [==============================] - 17s 19ms/step - loss: 0.2452
# Epoch 2/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1582
# Epoch 3/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0827
# Epoch 4/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0525
# Epoch 5/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0607
# Epoch 6/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0691
# Epoch 7/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0641
# Epoch 8/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0642
# Epoch 9/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0629
# Epoch 10/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0651
# Epoch 11/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0654
# Epoch 12/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0590
# Epoch 13/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0598
# Epoch 14/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0566
# Epoch 15/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0579
# Epoch 16/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0550
# Epoch 17/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0564
# Epoch 18/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0543
# Epoch 19/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0525
# Epoch 20/500
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0517
# Epoch 21/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0531
# Epoch 22/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0515
# Epoch 23/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0571
# Epoch 24/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0467
# Epoch 25/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0512
# Epoch 26/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0528
# Epoch 27/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0512
# Epoch 28/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0516
# Epoch 29/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0497
# Epoch 30/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0493
# Epoch 31/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0547
# Epoch 32/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0469
# Epoch 33/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0492
# Epoch 34/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0502
# Epoch 35/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0546
# Epoch 36/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0475
# Epoch 37/500
# 13/13 [==============================] - ETA: 0s - loss: 0.045 - 0s 19ms/step - loss: 0.0452
# Epoch 38/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0510
# Epoch 39/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0530
# Epoch 40/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0512
# Epoch 41/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0498
# Epoch 42/500
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0489
# Epoch 43/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0505
# Epoch 44/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0467
# Epoch 45/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0452
# Epoch 46/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0468
# Epoch 47/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0466
# Epoch 48/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0497
# Epoch 49/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0495
# Epoch 50/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0459
# Epoch 51/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0471
# Epoch 52/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0496
# Epoch 53/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0501
# Epoch 54/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0485
# Epoch 55/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0439
# Epoch 56/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0459
# Epoch 57/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0469
# Epoch 58/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0500
# Epoch 59/500
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0469
# Epoch 60/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0474
# Epoch 61/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0457
# Epoch 62/500
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0454
# Epoch 63/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0464
# Epoch 64/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0432
# Epoch 65/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0482
# Epoch 66/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0478
# Epoch 67/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0468
# Epoch 68/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0496
# Epoch 69/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0457
# Epoch 70/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0479
# Epoch 71/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0470
# Epoch 72/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0476
# Epoch 73/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0480
# Epoch 74/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0425
# Epoch 75/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0482
# Epoch 76/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0465
# Epoch 77/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0517
# Epoch 78/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0487
# Epoch 79/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0448
# Epoch 80/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0478
# Epoch 81/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0463
# Epoch 82/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0468
# Epoch 83/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0522
# Epoch 84/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0457
# Epoch 85/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0464
# Epoch 86/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0479
# Epoch 87/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0461
# Epoch 88/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0440
# Epoch 89/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0456
# Epoch 90/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0496
# Epoch 91/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0465
# Epoch 92/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0430
# Epoch 93/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0440
# Epoch 94/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0467
# Epoch 95/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0463
# Epoch 96/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0430
# Epoch 97/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0439
# Epoch 98/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0451
# Epoch 99/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0430
# Epoch 100/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0481
# Epoch 101/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0482
# Epoch 102/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0482
# Epoch 103/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0429
# Epoch 104/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0446
# Epoch 105/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0428
# Epoch 106/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0475
# Epoch 107/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0469
# Epoch 108/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0469
# Epoch 109/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0457
# Epoch 110/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0447
# Epoch 111/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0416
# Epoch 112/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0469
# Epoch 113/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0421
# Epoch 114/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0469
# Epoch 115/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0434
# Epoch 116/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0454
# Epoch 117/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0447
# Epoch 118/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0427
# Epoch 119/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0454
# Epoch 120/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0426
# Epoch 121/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0452
# Epoch 122/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0464
# Epoch 123/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0438
# Epoch 124/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0482
# Epoch 125/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0464
# Epoch 126/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0454
# Epoch 127/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0457
# Epoch 128/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0490
# Epoch 129/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0456
# Epoch 130/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0457
# Epoch 131/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0463
# Epoch 132/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0454
# Epoch 133/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0469
# Epoch 134/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0482
# Epoch 135/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0443
# Epoch 136/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0451
# Epoch 137/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0429
# Epoch 138/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0466
# Epoch 139/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0481
# Epoch 140/500
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0427
# Epoch 141/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0419
# Epoch 142/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0430
# Epoch 143/500
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0454
# Epoch 144/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0475
# Epoch 145/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0462
# Epoch 146/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0417
# Epoch 147/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0431
# Epoch 148/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0421
# Epoch 149/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0449
# Epoch 150/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0448
# Epoch 151/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0453
# Epoch 152/500
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0446
# Epoch 153/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0423
# Epoch 154/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0432
# Epoch 155/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0435
# Epoch 156/500
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0452
# Epoch 157/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0451
# Epoch 158/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0460
# Epoch 159/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0476
# Epoch 160/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0453
# Epoch 161/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0458
# Epoch 162/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0483
# Epoch 163/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0447
# Epoch 164/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0472
# Epoch 165/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0443
# Epoch 166/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0410
# Epoch 167/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0449
# Epoch 168/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0450
# Epoch 169/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0445
# Epoch 170/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0437
# Epoch 171/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0451
# Epoch 172/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0436
# Epoch 173/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0438
# Epoch 174/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0451
# Epoch 175/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0446
# Epoch 176/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0430
# Epoch 177/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0430
# Epoch 178/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0438
# Epoch 179/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0444
# Epoch 180/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0457
# Epoch 181/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0414
# Epoch 182/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0447
# Epoch 183/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0424
# Epoch 184/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0435
# Epoch 185/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0451
# Epoch 186/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0434
# Epoch 187/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0446
# Epoch 188/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0448
# Epoch 189/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0450
# Epoch 190/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0426
# Epoch 191/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0477
# Epoch 192/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0453
# Epoch 193/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0415
# Epoch 194/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0435
# Epoch 195/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0427
# Epoch 196/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0430
# Epoch 197/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0449
# Epoch 198/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0418
# Epoch 199/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0437
# Epoch 200/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0458
# Epoch 201/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0418
# Epoch 202/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0411
# Epoch 203/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0440
# Epoch 204/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0459
# Epoch 205/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0452
# Epoch 206/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0416
# Epoch 207/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0410
# Epoch 208/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0423
# Epoch 209/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0443
# Epoch 210/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0465
# Epoch 211/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0435
# Epoch 212/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0453
# Epoch 213/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0428
# Epoch 214/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0467
# Epoch 215/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0418
# Epoch 216/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0480
# Epoch 217/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0445
# Epoch 218/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0421
# Epoch 219/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0420
# Epoch 220/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0436
# Epoch 221/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0443
# Epoch 222/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0422
# Epoch 223/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0413
# Epoch 224/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0449
# Epoch 225/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0427
# Epoch 226/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0447
# Epoch 227/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0441
# Epoch 228/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0454
# Epoch 229/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0438
# Epoch 230/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0431
# Epoch 231/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0431
# Epoch 232/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0395
# Epoch 233/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0428
# Epoch 234/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0434
# Epoch 235/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0451
# Epoch 236/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0410
# Epoch 237/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0418
# Epoch 238/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0448
# Epoch 239/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0418
# Epoch 240/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0422
# Epoch 241/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0401
# Epoch 242/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0440
# Epoch 243/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0401
# Epoch 244/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0427
# Epoch 245/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0427
# Epoch 246/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0402
# Epoch 247/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0394
# Epoch 248/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0428
# Epoch 249/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0441
# Epoch 250/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0421
# Epoch 251/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0409
# Epoch 252/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0426
# Epoch 253/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0422
# Epoch 254/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0433
# Epoch 255/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0430
# Epoch 256/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0427
# Epoch 257/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0412
# Epoch 258/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0418
# Epoch 259/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0429
# Epoch 260/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0427
# Epoch 261/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0411
# Epoch 262/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0410
# Epoch 263/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0409
# Epoch 264/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0428
# Epoch 265/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0427
# Epoch 266/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0425
# Epoch 267/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0415
# Epoch 268/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0416
# Epoch 269/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0421
# Epoch 270/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0416
# Epoch 271/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0426
# Epoch 272/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0422
# Epoch 273/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0401
# Epoch 274/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0398
# Epoch 275/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0430
# Epoch 276/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0410
# Epoch 277/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0410
# Epoch 278/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0421
# Epoch 279/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0400
# Epoch 280/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0431
# Epoch 281/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0451
# Epoch 282/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0442
# Epoch 283/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0442
# Epoch 284/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0423
# Epoch 285/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0430
# Epoch 286/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0434
# Epoch 287/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0438
# Epoch 288/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0409
# Epoch 289/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0413
# Epoch 290/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0404
# Epoch 291/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0418
# Epoch 292/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0435
# Epoch 293/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0392
# Epoch 294/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0416
# Epoch 295/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0431
# Epoch 296/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0432
# Epoch 297/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0417
# Epoch 298/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0400
# Epoch 299/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0422
# Epoch 300/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0401
# Epoch 301/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0415
# Epoch 302/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0414
# Epoch 303/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0424
# Epoch 304/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0403
# Epoch 305/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0422
# Epoch 306/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0433
# Epoch 307/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0408
# Epoch 308/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0390
# Epoch 309/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0406
# Epoch 310/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0413
# Epoch 311/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0438
# Epoch 312/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0451
# Epoch 313/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0434
# Epoch 314/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0427
# Epoch 315/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0392
# Epoch 316/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0427
# Epoch 317/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0394
# Epoch 318/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0426
# Epoch 319/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0418
# Epoch 320/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0415
# Epoch 321/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0407
# Epoch 322/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0419
# Epoch 323/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0424
# Epoch 324/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0437
# Epoch 325/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0401
# Epoch 326/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0408
# Epoch 327/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0395
# Epoch 328/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0417
# Epoch 329/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0412
# Epoch 330/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0429
# Epoch 331/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0411
# Epoch 332/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0404
# Epoch 333/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0407
# Epoch 334/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0440
# Epoch 335/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0408
# Epoch 336/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0416
# Epoch 337/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0438
# Epoch 338/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0410
# Epoch 339/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0406
# Epoch 340/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0396
# Epoch 341/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0410
# Epoch 342/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0423
# Epoch 343/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0391
# Epoch 344/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0406
# Epoch 345/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0403
# Epoch 346/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0427
# Epoch 347/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0392
# Epoch 348/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0417
# Epoch 349/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0393
# Epoch 350/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0394
# Epoch 351/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0398
# Epoch 352/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0415
# Epoch 353/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0414
# Epoch 354/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0433
# Epoch 355/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0426
# Epoch 356/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0411
# Epoch 357/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0396
# Epoch 358/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0409
# Epoch 359/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0422
# Epoch 360/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0385
# Epoch 361/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0414
# Epoch 362/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0406
# Epoch 363/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0414
# Epoch 364/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0425
# Epoch 365/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0388
# Epoch 366/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0421
# Epoch 367/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0386
# Epoch 368/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0390
# Epoch 369/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0416
# Epoch 370/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0428
# Epoch 371/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0428
# Epoch 372/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0404
# Epoch 373/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0412
# Epoch 374/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0404
# Epoch 375/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0412
# Epoch 376/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0408
# Epoch 377/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0401
# Epoch 378/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0426
# Epoch 379/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0405
# Epoch 380/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0423
# Epoch 381/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0406
# Epoch 382/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0409
# Epoch 383/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0412
# Epoch 384/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0402
# Epoch 385/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0387
# Epoch 386/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0400
# Epoch 387/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0400
# Epoch 388/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0423
# Epoch 389/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0419
# Epoch 390/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0403
# Epoch 391/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0402
# Epoch 392/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0393
# Epoch 393/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0391
# Epoch 394/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0410
# Epoch 395/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0402
# Epoch 396/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0397
# Epoch 397/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0400
# Epoch 398/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0407
# Epoch 399/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0405
# Epoch 400/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0389
# Epoch 401/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0385
# Epoch 402/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0408
# Epoch 403/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0394
# Epoch 404/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0395
# Epoch 405/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0402
# Epoch 406/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0410
# Epoch 407/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0411
# Epoch 408/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0422
# Epoch 409/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0381
# Epoch 410/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0402
# Epoch 411/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0367
# Epoch 412/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0378
# Epoch 413/500
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0406
# Epoch 414/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0413
# Epoch 415/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0418
# Epoch 416/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0395
# Epoch 417/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0385
# Epoch 418/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0381
# Epoch 419/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0406
# Epoch 420/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0376
# Epoch 421/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0380
# Epoch 422/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0395
# Epoch 423/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0384
# Epoch 424/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0377
# Epoch 425/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0385
# Epoch 426/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0401
# Epoch 427/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0393
# Epoch 428/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0401
# Epoch 429/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0402
# Epoch 430/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0398
# Epoch 431/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0381
# Epoch 432/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0382
# Epoch 433/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0377
# Epoch 434/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0380
# Epoch 435/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0393
# Epoch 436/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0381
# Epoch 437/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0394
# Epoch 438/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0372
# Epoch 439/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0398
# Epoch 440/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0399
# Epoch 441/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0394
# Epoch 442/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0380
# Epoch 443/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0392
# Epoch 444/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0412
# Epoch 445/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0391
# Epoch 446/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0401
# Epoch 447/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0385
# Epoch 448/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0389
# Epoch 449/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0392
# Epoch 450/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0381
# Epoch 451/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0403
# Epoch 452/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0392
# Epoch 453/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0394
# Epoch 454/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0383
# Epoch 455/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0386
# Epoch 456/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0379
# Epoch 457/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0388
# Epoch 458/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0398
# Epoch 459/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0384
# Epoch 460/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0410
# Epoch 461/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0378
# Epoch 462/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0403
# Epoch 463/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0372
# Epoch 464/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0399
# Epoch 465/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0372
# Epoch 466/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0381
# Epoch 467/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0384
# Epoch 468/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0394
# Epoch 469/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0398
# Epoch 470/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0385
# Epoch 471/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0370
# Epoch 472/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0393
# Epoch 473/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0400
# Epoch 474/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0381
# Epoch 475/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0398
# Epoch 476/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0371
# Epoch 477/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0391
# Epoch 478/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0394
# Epoch 479/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0369
# Epoch 480/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0370
# Epoch 481/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0399
# Epoch 482/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0414
# Epoch 483/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0401
# Epoch 484/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0389
# Epoch 485/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0376
# Epoch 486/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0385
# Epoch 487/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0402
# Epoch 488/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0392
# Epoch 489/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0385
# Epoch 490/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0398
# Epoch 491/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0402
# Epoch 492/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0400
# Epoch 493/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0365
# Epoch 494/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0357
# Epoch 495/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0376
# Epoch 496/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0384
# Epoch 497/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0370
# Epoch 498/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0383
# Epoch 499/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0387
# Epoch 500/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0379

# %% [markdown]
# ---

# %% [markdown]
# ## Model Performance
#
# In this section, you will evaluate the model using the test data.
#
# You will need to:
# 1. Evaluate the model using the `X_test` and `y_test` data.
# 2. Use the X_test data to make predictions
# 3. Create a DataFrame of Real (y_test) vs predicted values.
# 4. Plot the Real vs predicted values as a line chart
#
# ### Hints
# Remember to apply the `inverse_transform` function to the predicted and y_test values to recover the actual closing prices.

# %%
# Plotting loss
loss_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": training_history.history["loss"],
    }
)
loss_df.set_index("Epoch", inplace=True)
loss_fng_plot = loss_df.plot(title="Loss")
loss_fng_plot
loss_fng_plot.figure.savefig(Path("../deep_learning_homework_uw_fintech/Images/loss_fng_plot.png"))

# %%
# Evaluate the model
# YOUR CODE HERE!
model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 2s 6ms/step - loss: 0.1226
# 0.1225685328245163

# %%
# Make some predictions
# YOUR CODE HERE!
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
}, index = df.index[-len(real_prices): ]) 
stocks.head()
# Out:
#                    Real    Predicted
# 2019-02-20  3924.239990  7458.968750
# 2019-02-21  3974.050049  7764.551270
# 2019-02-22  3937.040039  8018.493164
# 2019-02-23  3983.530029  8402.869141
# 2019-02-24  4149.089844  8578.261719

# %%
# Plot the real vs predicted values as a line chart
# YOUR CODE HERE!
fng_plot = stocks.plot()
fng_plot
fng_plot.figure.savefig(Path("../deep_learning_homework_uw_fintech/Images/fng_plot.png"))
